# %% [markdown]
# <a href="https://colab.research.google.com/github/saumyajeet1822/PRODIGY_DS_01/blob/main/TASK_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data Science Intern At Prodigy Infotech

# %% [markdown]
# Author : **Saumyajeet Das**
#
# Task 1: Create a bar chart or histogram to visualize the distribution of a categorical or continuous variable.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('climate-ds.csv',index_col=0)
df.head()
# Out:
#       Area         Item  Year  average_rain_fall_mm_per_year  \
# 0  Albania        Maize  1990                           1485
# 1  Albania     Potatoes  1990                           1485
# 2  Albania  Rice, paddy  1990                           1485
# 3  Albania      Sorghum  1990                           1485
# 4  Albania     Soybeans  1990                           1485
#
#    pesticides_tonnes  avg_temp  hg/ha_yield
# 0              121.0     16.37        36613
# 1              121.0     16.37        66667
# 2              121.0     16.37        23333
# 3              121.0     16.37        12500
# 4              121.0     16.37         7000

# %%
#rows and columns
df.shape
# Out:
# (28242, 7)
